# %%
pip install langchain==0.1.0 openai==1.7.2 langchain-openai==0.0.2 langchain-community==0.0.12 langchainhub==0.1.14
# Out:
# Requirement already satisfied: langchain==0.1.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (0.1.0)
# Requirement already satisfied: openai==1.7.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (1.7.2)
# Requirement already satisfied: langchain-openai==0.0.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (0.0.2)
# Requirement already satisfied: langchain-community==0.0.12 in /usr/local/python/3.10.13/lib/python3.10/site-packages (0.0.12)
# Requirement already satisfied: langchainhub==0.1.14 in /usr/local/python/3.10.13/lib/python3.10/site-packages (0.1.14)
# Requirement already satisfied: PyYAML>=5.3 in /home/codespace/.local/lib/python3.10/site-packages (from langchain==0.1.0) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain==0.1.0) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain==0.1.0) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain==0.1.0) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain==0.1.0) (0.6.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain==0.1.0) (1.33)
# Requirement already satisfied: langchain-core<0.2,>=0.1.7 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain==0.1.0) (0.1.23)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.77 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain==0.1.0) (0.0.87)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain==0.1.0) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain==0.1.0) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from langchain==0.1.0) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /home/codespace/.local/lib/python3.10/site-packages (from langchain==0.1.0) (8.5.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/codespace/.local/lib/python3.10/site-packages (from openai==1.7.2) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from openai==1.7.2) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/codespace/.local/lib/python3.10/site-packages (from openai==1.7.2) (0.27.0)
# Requirement already satisfied: sniffio in /home/codespace/.local/lib/python3.10/site-packages (from openai==1.7.2) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from openai==1.7.2) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /home/codespace/.local/lib/python3.10/site-packages (from openai==1.7.2) (4.12.2)
# Requirement already satisfied: tiktoken<0.6.0,>=0.5.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain-openai==0.0.2) (0.5.2)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchainhub==0.1.14) (2.32.0.20240712)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/codespace/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.0) (1.9.4)
# Requirement already satisfied: idna>=2.8 in /home/codespace/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai==1.7.2) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/codespace/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai==1.7.2) (1.2.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.0) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.0) (0.9.0)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai==1.7.2) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai==1.7.2) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/codespace/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.7.2) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/codespace/.local/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain==0.1.0) (3.0.0)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from langchain-core<0.2,>=0.1.7->langchain==0.1.0) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pydantic<3,>=1->langchain==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pydantic<3,>=1->langchain==0.1.0) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3,>=2->langchain==0.1.0) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from requests<3,>=2->langchain==0.1.0) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain==0.1.0) (3.0.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from tiktoken<0.6.0,>=0.5.2->langchain-openai==0.0.2) (2024.7.24)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.1.0) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /usr/local/python/3.10.13/lib/python3.10/site-packages (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.schema.messages import HumanMessage, SystemMessage
from langchain_intro.chatbot import chat_model

# %%
messages = [SystemMessage(content="""You're an assistant knowledgeable about healthcare. Only answer healthcare-related questions."""), 
HumanMessage(content="What is Medicaid managed care?")]

# %%
chat_model.invoke(messages)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 chat_model.invoke(messages)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:166, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     155 def invoke(
#     156     self,
#     157     input: LanguageModelInput,
#    (...)
#     161     **kwargs: Any,
#     162 ) -> BaseMessage:
#     163     config = ensure_config(config)
#     164     return cast(
#     165         ChatGeneration,
# --> 166         self.generate_prompt(
#     167             [self._convert_input(input)],
#     168             stop=stop,
#     169             callbacks=config.get("callbacks"),
#     170             tags=config.get("tags"),
#     171             metadata=config.get("metadata"),
#     172             run_name=config.get("run_name"),
#     173             **kwargs,
#     174         ).generations[0][0],
#     175     ).message
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:544, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     536 def generate_prompt(
#     537     self,
#     538     prompts: List[PromptValue],
#    (...)
#     541     **kwargs: Any,
#     542 ) -> LLMResult:
#     543     prompt_messages = [p.to_messages() for p in prompts]
# --> 544     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:408, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, **kwargs)
#     406         if run_managers:
#     407             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 408         raise e
#     409 flattened_outputs = [
#     410     LLMResult(generations=[res.generations], llm_output=res.llm_output)
#     411     for res in results
#     412 ]
#     413 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:398, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, **kwargs)
#     395 for i, m in enumerate(messages):
#     396     try:
#     397         results.append(
# --> 398             self._generate_with_cache(
#     399                 m,
#     400                 stop=stop,
#     401                 run_manager=run_managers[i] if run_managers else None,
#     402                 **kwargs,
#     403             )
#     404         )
#     405     except BaseException as e:
#     406         if run_managers:
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:577, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     573     raise ValueError(
#     574         "Asked to cache, but no cache found at `langchain.cache`."
#     575     )
#     576 if new_arg_supported:
# --> 577     return self._generate(
#     578         messages, stop=stop, run_manager=run_manager, **kwargs
#     579     )
#     580 else:
#     581     return self._generate(messages, stop=stop, **kwargs)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:437, in ChatOpenAI._generate(self, messages, stop, run_manager, stream, **kwargs)
#     431 message_dicts, params = self._create_message_dicts(messages, stop)
#     432 params = {
#     433     **params,
#     434     **({"stream": stream} if stream is not None else {}),
#     435     **kwargs,
#     436 }
# --> 437 response = self.client.create(messages=message_dicts, **params)
#     438 return self._create_chat_result(response)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/openai/_utils/_utils.py:271, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     269             msg = f"Missing required argument: {quote(missing[0])}"
#     270     raise TypeError(msg)
# --> 271 return func(*args, **kwargs)
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/openai/resources/chat/completions.py:643, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     594 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     595 def create(
#     596     self,
#    (...)
#     641     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     642 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 643     return self._post(
#     644         "/chat/completions",
#     645         body=maybe_transform(
#     646             {
#     647                 "messages": messages,
#     648                 "model": model,
#     649                 "frequency_penalty": frequency_penalty,
#     650                 "function_call": function_call,
#     651                 "functions": functions,
#     652                 "logit_bias": logit_bias,
#     653                 "logprobs": logprobs,
#     654                 "max_tokens": max_tokens,
#     655                 "n": n,
#     656                 "presence_penalty": presence_penalty,
#     657                 "response_format": response_format,
#     658                 "seed": seed,
#     659                 "stop": stop,
#     660                 "stream": stream,
#     661                 "temperature": temperature,
#     662                 "tool_choice": tool_choice,
#     663                 "tools": tools,
#     664                 "top_logprobs": top_logprobs,
#     665                 "top_p": top_p,
#     666                 "user": user,
#     667             },
#     668             completion_create_params.CompletionCreateParams,
#     669         ),
#     670         options=make_request_options(
#     671             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     672         ),
#     673         cast_to=ChatCompletion,
#     674         stream=stream or False,
#     675         stream_cls=Stream[ChatCompletionChunk],
#     676     )
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/openai/_base_client.py:1112, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1098 def post(
#    1099     self,
#    1100     path: str,
#    (...)
#    1107     stream_cls: type[_StreamT] | None = None,
#    1108 ) -> ResponseT | _StreamT:
#    1109     opts = FinalRequestOptions.construct(
#    1110         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1111     )
# -> 1112     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/openai/_base_client.py:859, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     850 def request(
#     851     self,
#     852     cast_to: Type[ResponseT],
#    (...)
#     857     stream_cls: type[_StreamT] | None = None,
#     858 ) -> ResponseT | _StreamT:
# --> 859     return self._request(
#     860         cast_to=cast_to,
#     861         options=options,
#     862         stream=stream,
#     863         stream_cls=stream_cls,
#     864         remaining_retries=remaining_retries,
#     865     )
#
# File /usr/local/python/3.10.13/lib/python3.10/site-packages/openai/_base_client.py:949, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     946         err.response.read()
#     948     log.debug("Re-raising status error")
# --> 949     raise self._make_status_error_from_response(err.response) from None
#     951 return self._process_response(
#     952     cast_to=cast_to,
#     953     options=options,
#    (...)
#     956     stream_cls=stream_cls,
#     957 )
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-j5NXB***************************************yplA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}

# %%
from langchain_intro.chatbot import review_chain
